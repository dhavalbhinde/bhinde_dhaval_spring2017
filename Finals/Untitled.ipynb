# %%
import requests

url = "https://data.cityofnewyork.us/resource/fhrw-4uyv.json"

response = requests.get(url)
if response.status_code == 200:
    data = response.json()

# %%
data
# Out:
# [{':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:17:08.000',
#   'descriptor': 'Graffiti',
#   'facility_type': 'N/A',
#   'incident_address': '493 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.80932156221716',
#   'location': {'coordinates': [-73.919357, 40.809322], 'type': 'Point'},
#   'location_type': 'Residential',
#   'longitude': '-73.9193573152392',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:17:08.000',
#   'resolution_description': 'The graffiti has been reported. The property owner will be notified that the City will remove the graffiti after 35 days unless the property owner requests to keep the graffiti or remove it himself or herself.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35950274',
#   'x_coordinate_state_plane': '1006574',
#   'y_coordinate_state_plane': '234145'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:16:40.000',
#   'descriptor': 'Graffiti',
#   'facility_type': 'N/A',
#   'incident_address': '489 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.80936005145562',
#   'location': {'coordinates': [-73.919448, 40.80936], 'type': 'Point'},
#   'location_type': 'Residential',
#   'longitude': '-73.91944757808554',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:16:40.000',
#   'resolution_description': 'The graffiti has been reported. The property owner will be notified that the City will remove the graffiti after 35 days unless the property owner requests to keep the graffiti or remove it himself or herself.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35951912',
#   'x_coordinate_state_plane': '1006549',
#   'y_coordinate_state_plane': '234159'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:16:26.000',
#   'descriptor': 'Graffiti',
#   'facility_type': 'N/A',
#   'incident_address': '485 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.80939579338032',
#   'location': {'coordinates': [-73.919534, 40.809396], 'type': 'Point'},
#   'location_type': 'Residential',
#   'longitude': '-73.91953423197629',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:16:26.000',
#   'resolution_description': 'The graffiti has been reported. The property owner will be notified that the City will remove the graffiti after 35 days unless the property owner requests to keep the graffiti or remove it himself or herself.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35953646',
#   'x_coordinate_state_plane': '1006525',
#   'y_coordinate_state_plane': '234172'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:16:05.000',
#   'descriptor': 'Graffiti',
#   'facility_type': 'N/A',
#   'incident_address': '481 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.80943428247981',
#   'location': {'coordinates': [-73.919624, 40.809434], 'type': 'Point'},
#   'location_type': 'Residential',
#   'longitude': '-73.9196244950256',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:16:05.000',
#   'resolution_description': 'The graffiti has been reported. The property owner will be notified that the City will remove the graffiti after 35 days unless the property owner requests to keep the graffiti or remove it himself or herself.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35955357',
#   'x_coordinate_state_plane': '1006500',
#   'y_coordinate_state_plane': '234186'},
#  {':@computed_region_92fq_4b7q': '1',
#   ':@computed_region_efsh_h5xi': '10099',
#   ':@computed_region_f5dn_yrer': '23',
#   ':@computed_region_yeji_bk3q': '4',
#   'address_type': 'BLOCKFACE',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'MANHATTAN',
#   'city': 'NEW YORK',
#   'community_board': '08 MANHATTAN',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2017-04-16T02:15:28.000',
#   'cross_street_1': '3 AVENUE',
#   'cross_street_2': '2 AVENUE',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T10:15:28.000',
#   'facility_type': 'Precinct',
#   'incident_address': 'EAST 88 STREET',
#   'incident_zip': '10128',
#   'latitude': '40.77964999760072',
#   'location': {'coordinates': [-73.951915, 40.77965], 'type': 'Point'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.95191542770513',
#   'park_borough': 'MANHATTAN',
#   'park_facility_name': 'Unspecified',
#   'resolution_description': 'Your complaint has been forwarded to the New York Police Department for a non-emergency response. 311 will have additional information in 8 hours. Please note your service request number for future reference.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST 88 STREET',
#   'unique_key': '35950072',
#   'x_coordinate_state_plane': '997567',
#   'y_coordinate_state_plane': '223328'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:14:54.000',
#   'descriptor': 'Graffiti',
#   'facility_type': 'N/A',
#   'incident_address': '475 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.80949201473899',
#   'location': {'coordinates': [-73.919758, 40.809492], 'type': 'Point'},
#   'location_type': 'Residential',
#   'longitude': '-73.91975808360364',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:14:54.000',
#   'resolution_description': 'The graffiti has been reported. The property owner will be notified that the City will remove the graffiti after 35 days unless the property owner requests to keep the graffiti or remove it himself or herself.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35949496',
#   'x_coordinate_state_plane': '1006463',
#   'y_coordinate_state_plane': '234207'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '12426',
#   ':@computed_region_f5dn_yrer': '7',
#   ':@computed_region_yeji_bk3q': '4',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'MANHATTAN',
#   'city': 'NEW YORK',
#   'community_board': '11 MANHATTAN',
#   'complaint_type': 'Noise - Street/Sidewalk',
#   'created_date': '2017-04-16T02:14:53.000',
#   'cross_street_1': 'LEXINGTON AVENUE',
#   'cross_street_2': '3 AVENUE',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T10:14:53.000',
#   'facility_type': 'Precinct',
#   'incident_address': '176 EAST 106 STREET',
#   'incident_zip': '10029',
#   'latitude': '40.79183092895628',
#   'location': {'coordinates': [-73.945319, 40.791831], 'type': 'Point'},
#   'location_type': 'Street/Sidewalk',
#   'longitude': '-73.94531938668834',
#   'park_borough': 'MANHATTAN',
#   'park_facility_name': 'Unspecified',
#   'resolution_description': 'Your complaint has been forwarded to the New York Police Department for a non-emergency response. 311 will have additional information in 8 hours. Please note your service request number for future reference.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST 106 STREET',
#   'unique_key': '35952445',
#   'x_coordinate_state_plane': '999391',
#   'y_coordinate_state_plane': '227767'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:14:39.000',
#   'descriptor': 'Graffiti',
#   'facility_type': 'N/A',
#   'incident_address': '471 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.80952775894101',
#   'location': {'coordinates': [-73.919848, 40.809528], 'type': 'Point'},
#   'location_type': 'Residential',
#   'longitude': '-73.91984835021823',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:14:39.000',
#   'resolution_description': 'The graffiti has been reported. The property owner will be notified that the City will remove the graffiti after 35 days unless the property owner requests to keep the graffiti or remove it himself or herself.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35951907',
#   'x_coordinate_state_plane': '1006438',
#   'y_coordinate_state_plane': '234220'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:14:21.000',
#   'descriptor': 'Graffiti',
#   'due_date': '2017-05-16T02:14:21.000',
#   'facility_type': 'N/A',
#   'incident_address': '466 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.80955253171107',
#   'location': {'coordinates': [-73.919949, 40.809553], 'type': 'Point'},
#   'location_type': 'Comercial',
#   'longitude': '-73.9199494672962',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:14:21.000',
#   'resolution_description': 'The graffiti on this property has been scheduled to be removed by the City.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35951014',
#   'x_coordinate_state_plane': '1006410',
#   'y_coordinate_state_plane': '234229'},
#  {':@computed_region_92fq_4b7q': '43',
#   ':@computed_region_efsh_h5xi': '10937',
#   ':@computed_region_f5dn_yrer': '8',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '02 BRONX',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2017-04-16T02:14:14.000',
#   'cross_street_1': 'PROSPECT AVENUE',
#   'cross_street_2': 'EAST 163 STREET',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T10:14:14.000',
#   'facility_type': 'Precinct',
#   'incident_address': '881 EAST 162 STREET',
#   'incident_zip': '10459',
#   'latitude': '40.82127039726054',
#   'location': {'coordinates': [-73.89972, 40.82127], 'type': 'Point'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.89972048984208',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_description': 'Your complaint has been forwarded to the New York Police Department for a non-emergency response. 311 will have additional information in 8 hours. Please note your service request number for future reference.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST 162 STREET',
#   'unique_key': '35951680',
#   'x_coordinate_state_plane': '1012005',
#   'y_coordinate_state_plane': '238504'},
#  {':@computed_region_92fq_4b7q': '12',
#   ':@computed_region_efsh_h5xi': '11607',
#   ':@computed_region_f5dn_yrer': '59',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '11 BRONX',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2017-04-16T02:14:01.000',
#   'cross_street_1': 'BEND',
#   'cross_street_2': 'BEND',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T10:14:01.000',
#   'facility_type': 'Precinct',
#   'incident_address': '21 GABRIEL DRIVE',
#   'incident_zip': '10469',
#   'latitude': '40.86378496765669',
#   'location': {'coordinates': [-73.850614, 40.863785], 'type': 'Point'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.85061432517338',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:23:59.000',
#   'resolution_description': 'Your complaint has been received by the Police Department and additional information will be available later.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Assigned',
#   'street_name': 'GABRIEL DRIVE',
#   'unique_key': '35955854',
#   'x_coordinate_state_plane': '1025570',
#   'y_coordinate_state_plane': '254013'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '13093',
#   ':@computed_region_f5dn_yrer': '7',
#   ':@computed_region_yeji_bk3q': '4',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'MANHATTAN',
#   'city': 'NEW YORK',
#   'community_board': '11 MANHATTAN',
#   'complaint_type': 'Noise - Commercial',
#   'created_date': '2017-04-16T02:13:57.000',
#   'cross_street_1': '3 AVENUE',
#   'cross_street_2': '2 AVENUE',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T10:13:57.000',
#   'facility_type': 'Precinct',
#   'incident_address': '209 EAST 117 STREET',
#   'incident_zip': '10035',
#   'latitude': '40.798437093873915',
#   'location': {'coordinates': [-73.939051, 40.798437], 'type': 'Point'},
#   'location_type': 'Club/Bar/Restaurant',
#   'longitude': '-73.9390511237502',
#   'park_borough': 'MANHATTAN',
#   'park_facility_name': 'Unspecified',
#   'resolution_description': 'Your complaint has been forwarded to the New York Police Department for a non-emergency response. 311 will have additional information in 8 hours. Please note your service request number for future reference.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST 117 STREET',
#   'unique_key': '35953113',
#   'x_coordinate_state_plane': '1001125',
#   'y_coordinate_state_plane': '230175'},
#  {':@computed_region_92fq_4b7q': '21',
#   ':@computed_region_efsh_h5xi': '14510',
#   ':@computed_region_f5dn_yrer': '65',
#   ':@computed_region_yeji_bk3q': '3',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'QUEENS',
#   'city': 'CORONA',
#   'community_board': '03 QUEENS',
#   'complaint_type': 'Noise - Commercial',
#   'created_date': '2017-04-16T02:13:56.000',
#   'cross_street_1': '37 AVENUE',
#   'cross_street_2': '39 AVENUE',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T10:13:56.000',
#   'facility_type': 'Precinct',
#   'incident_address': '37-30 103 STREET',
#   'incident_zip': '11368',
#   'latitude': '40.75282153277659',
#   'location': {'coordinates': [-73.864228, 40.752822], 'type': 'Point'},
#   'location_type': 'Store/Commercial',
#   'longitude': '-73.864228466777',
#   'park_borough': 'QUEENS',
#   'park_facility_name': 'Unspecified',
#   'resolution_description': 'Your complaint has been forwarded to the New York Police Department for a non-emergency response. 311 will have additional information in 8 hours. Please note your service request number for future reference.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': '103 STREET',
#   'unique_key': '35955999',
#   'x_coordinate_state_plane': '1021867',
#   'y_coordinate_state_plane': '213579'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:13:30.000',
#   'descriptor': 'Graffiti',
#   'facility_type': 'N/A',
#   'incident_address': '465 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.80958549093995',
#   'location': {'coordinates': [-73.919982, 40.809585], 'type': 'Point'},
#   'location_type': 'Residential',
#   'longitude': '-73.91998193917807',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:13:30.000',
#   'resolution_description': 'The graffiti has been reported. The property owner will be notified that the City will remove the graffiti after 35 days unless the property owner requests to keep the graffiti or remove it himself or herself.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35951908',
#   'x_coordinate_state_plane': '1006401',
#   'y_coordinate_state_plane': '234241'},
#  {':@computed_region_92fq_4b7q': '7',
#   ':@computed_region_efsh_h5xi': '17617',
#   ':@computed_region_f5dn_yrer': '9',
#   ':@computed_region_yeji_bk3q': '2',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'BROOKLYN',
#   'city': 'BROOKLYN',
#   'community_board': '07 BROOKLYN',
#   'complaint_type': 'Noise - Commercial',
#   'created_date': '2017-04-16T02:13:23.000',
#   'cross_street_1': '19 STREET',
#   'cross_street_2': '20 STREET',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T10:13:23.000',
#   'facility_type': 'Precinct',
#   'incident_address': '689 6 AVENUE',
#   'incident_zip': '11215',
#   'latitude': '40.660655143628304',
#   'location': {'coordinates': [-73.990542, 40.660655], 'type': 'Point'},
#   'location_type': 'Club/Bar/Restaurant',
#   'longitude': '-73.99054225150822',
#   'park_borough': 'BROOKLYN',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:27:32.000',
#   'resolution_description': 'Your complaint has been received by the Police Department and additional information will be available later.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Assigned',
#   'street_name': '6 AVENUE',
#   'unique_key': '35952426',
#   'x_coordinate_state_plane': '986874',
#   'y_coordinate_state_plane': '179971'},
#  {':@computed_region_92fq_4b7q': '37',
#   ':@computed_region_efsh_h5xi': '13828',
#   ':@computed_region_f5dn_yrer': '42',
#   ':@computed_region_yeji_bk3q': '2',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'BROOKLYN',
#   'city': 'BROOKLYN',
#   'community_board': '04 BROOKLYN',
#   'complaint_type': 'Noise - Street/Sidewalk',
#   'created_date': '2017-04-16T02:13:21.000',
#   'cross_street_1': 'KNICKERBOCKER AVENUE',
#   'cross_street_2': 'IRVING AVENUE',
#   'descriptor': 'Loud Talking',
#   'due_date': '2017-04-16T10:13:21.000',
#   'facility_type': 'Precinct',
#   'incident_address': '271 LINDEN STREET',
#   'incident_zip': '11237',
#   'latitude': '40.6977665109914',
#   'location': {'coordinates': [-73.915125, 40.697767], 'type': 'Point'},
#   'location_type': 'Street/Sidewalk',
#   'longitude': '-73.91512498209589',
#   'park_borough': 'BROOKLYN',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:31:27.000',
#   'resolution_description': 'Your complaint has been received by the Police Department and additional information will be available later.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Assigned',
#   'street_name': 'LINDEN STREET',
#   'unique_key': '35953234',
#   'x_coordinate_state_plane': '1007785',
#   'y_coordinate_state_plane': '193503'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:13:16.000',
#   'descriptor': 'Graffiti',
#   'facility_type': 'N/A',
#   'incident_address': '461 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.80962397968774',
#   'location': {'coordinates': [-73.920072, 40.809624], 'type': 'Point'},
#   'location_type': 'Residential',
#   'longitude': '-73.92007220274353',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:13:16.000',
#   'resolution_description': 'The graffiti has been reported. The property owner will be notified that the City will remove the graffiti after 35 days unless the property owner requests to keep the graffiti or remove it himself or herself.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35951913',
#   'x_coordinate_state_plane': '1006376',
#   'y_coordinate_state_plane': '234255'},
#  {':@computed_region_92fq_4b7q': '1',
#   ':@computed_region_efsh_h5xi': '12419',
#   ':@computed_region_f5dn_yrer': '71',
#   ':@computed_region_yeji_bk3q': '4',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'MANHATTAN',
#   'city': 'NEW YORK',
#   'community_board': '06 MANHATTAN',
#   'complaint_type': 'Noise - Commercial',
#   'created_date': '2017-04-16T02:13:07.000',
#   'cross_street_1': 'EAST 58 STREET',
#   'cross_street_2': 'EAST 59 STREET',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T10:13:07.000',
#   'facility_type': 'Precinct',
#   'incident_address': '1079 1 AVENUE',
#   'incident_zip': '10022',
#   'latitude': '40.75947171952833',
#   'location': {'coordinates': [-73.962088, 40.759472], 'type': 'Point'},
#   'location_type': 'Store/Commercial',
#   'longitude': '-73.96208761301712',
#   'park_borough': 'MANHATTAN',
#   'park_facility_name': 'Unspecified',
#   'resolution_description': 'Your complaint has been forwarded to the New York Police Department for a non-emergency response. 311 will have additional information in 8 hours. Please note your service request number for future reference.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': '1 AVENUE',
#   'unique_key': '35955986',
#   'x_coordinate_state_plane': '994753',
#   'y_coordinate_state_plane': '215975'},
#  {':@computed_region_92fq_4b7q': '11',
#   ':@computed_region_efsh_h5xi': '13510',
#   ':@computed_region_f5dn_yrer': '60',
#   ':@computed_region_yeji_bk3q': '2',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'BROOKLYN',
#   'city': 'BROOKLYN',
#   'community_board': '14 BROOKLYN',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2017-04-16T02:13:06.000',
#   'cross_street_1': 'TENNIS COURT',
#   'cross_street_2': 'ALBEMARLE ROAD',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T10:13:06.000',
#   'facility_type': 'Precinct',
#   'incident_address': '65 EAST 19 STREET',
#   'incident_zip': '11226',
#   'latitude': '40.647990264691344',
#   'location': {'coordinates': [-73.961827, 40.64799], 'type': 'Point'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.96182663286919',
#   'park_borough': 'BROOKLYN',
#   'park_facility_name': 'Unspecified',
#   'resolution_description': 'Your complaint has been forwarded to the New York Police Department for a non-emergency response. 311 will have additional information in 8 hours. Please note your service request number for future reference.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST 19 STREET',
#   'unique_key': '35950850',
#   'x_coordinate_state_plane': '994843',
#   'y_coordinate_state_plane': '175359'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:12:59.000',
#   'descriptor': 'Graffiti',
#   'facility_type': 'N/A',
#   'incident_address': '459 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.80964322528653',
#   'location': {'coordinates': [-73.920119, 40.809643], 'type': 'Point'},
#   'longitude': '-73.92011914076122',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:12:59.000',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35954479',
#   'x_coordinate_state_plane': '1006363',
#   'y_coordinate_state_plane': '234262'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:12:42.000',
#   'descriptor': 'Graffiti',
#   'facility_type': 'N/A',
#   'incident_address': '455 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.80967896670484',
#   'location': {'coordinates': [-73.920206, 40.809679], 'type': 'Point'},
#   'location_type': 'Residential',
#   'longitude': '-73.92020579538128',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:12:42.000',
#   'resolution_description': 'The graffiti has been reported. The property owner will be notified that the City will remove the graffiti after 35 days unless the property owner requests to keep the graffiti or remove it himself or herself.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35955358',
#   'x_coordinate_state_plane': '1006339',
#   'y_coordinate_state_plane': '234275'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:12:15.000',
#   'descriptor': 'Graffiti',
#   'facility_type': 'N/A',
#   'incident_address': '451 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.809717455276754',
#   'location': {'coordinates': [-73.920296, 40.809717], 'type': 'Point'},
#   'location_type': 'Residential',
#   'longitude': '-73.92029605920297',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:12:15.000',
#   'resolution_description': 'The graffiti has been reported. The property owner will be notified that the City will remove the graffiti after 35 days unless the property owner requests to keep the graffiti or remove it himself or herself.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35954493',
#   'x_coordinate_state_plane': '1006314',
#   'y_coordinate_state_plane': '234289'},
#  {':@computed_region_92fq_4b7q': '29',
#   ':@computed_region_efsh_h5xi': '10930',
#   ':@computed_region_f5dn_yrer': '50',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '04 BRONX',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2017-04-16T02:12:05.000',
#   'cross_street_1': 'EAST 172 STREET',
#   'cross_street_2': 'EAST MT EDEN AVENUE',
#   'descriptor': 'Banging/Pounding',
#   'due_date': '2017-04-16T10:12:05.000',
#   'facility_type': 'Precinct',
#   'incident_address': '1514 TOWNSEND AVENUE',
#   'incident_zip': '10452',
#   'latitude': '40.84251295360496',
#   'location': {'coordinates': [-73.91489, 40.842513], 'type': 'Point'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.91488970945723',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_description': 'Your complaint has been forwarded to the New York Police Department for a non-emergency response. 311 will have additional information in 8 hours. Please note your service request number for future reference.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'TOWNSEND AVENUE',
#   'unique_key': '35953130',
#   'x_coordinate_state_plane': '1007799',
#   'y_coordinate_state_plane': '246239'},
#  {':@computed_region_92fq_4b7q': '29',
#   ':@computed_region_efsh_h5xi': '10931',
#   ':@computed_region_f5dn_yrer': '6',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '05 BRONX',
#   'complaint_type': 'Noise - Street/Sidewalk',
#   'created_date': '2017-04-16T02:12:03.000',
#   'cross_street_1': 'CAMERON PLACE',
#   'cross_street_2': 'EAST 182 STREET',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T10:12:03.000',
#   'facility_type': 'Precinct',
#   'incident_address': '2201 WALTON AVENUE',
#   'incident_zip': '10453',
#   'latitude': '40.85647218162993',
#   'location': {'coordinates': [-73.903962, 40.856472], 'type': 'Point'},
#   'location_type': 'Street/Sidewalk',
#   'longitude': '-73.90396196201236',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_description': 'Your complaint has been forwarded to the New York Police Department for a non-emergency response. 311 will have additional information in 8 hours. Please note your service request number for future reference.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'WALTON AVENUE',
#   'unique_key': '35955702',
#   'x_coordinate_state_plane': '1010817',
#   'y_coordinate_state_plane': '251328'},
#  {':@computed_region_92fq_4b7q': '2',
#   ':@computed_region_efsh_h5xi': '11275',
#   ':@computed_region_f5dn_yrer': '29',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '12 BRONX',
#   'complaint_type': 'Blocked Driveway',
#   'created_date': '2017-04-16T02:11:47.000',
#   'cross_street_1': 'PAULDING AVENUE',
#   'cross_street_2': 'LACONIA AVENUE',
#   'descriptor': 'No Access',
#   'due_date': '2017-04-16T10:11:47.000',
#   'facility_type': 'Precinct',
#   'incident_address': '1057 EAST 231 STREET',
#   'incident_zip': '10466',
#   'latitude': '40.88880484264212',
#   'location': {'coordinates': [-73.847925, 40.888805], 'type': 'Point'},
#   'location_type': 'Street/Sidewalk',
#   'longitude': '-73.84792514341005',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_description': "Your complaint has been forwarded to the New York Police Department for a non-emergency response. If the police determine the vehicle is illegally parked, they will ticket the vehicle and then you may either contact a private towing company to remove the vehicle or ask your local precinct to contact 'rotation tow'. Any fees charged for towing will have to be paid by the vehicle owner. 311 will have additional information in 8 hours. Please note your service request number for future reference.",
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST 231 STREET',
#   'unique_key': '35950962',
#   'x_coordinate_state_plane': '1026298',
#   'y_coordinate_state_plane': '263130'},
#  {':@computed_region_92fq_4b7q': '37',
#   ':@computed_region_efsh_h5xi': '17215',
#   ':@computed_region_f5dn_yrer': '45',
#   ':@computed_region_yeji_bk3q': '2',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'BROOKLYN',
#   'city': 'BROOKLYN',
#   'community_board': '05 BROOKLYN',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2017-04-16T02:11:37.000',
#   'cross_street_1': 'RIDGEWOOD AVENUE',
#   'cross_street_2': 'ADLER PLACE',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T10:11:37.000',
#   'facility_type': 'Precinct',
#   'incident_address': '183 HEMLOCK STREET',
#   'incident_zip': '11208',
#   'latitude': '40.6853801043623',
#   'location': {'coordinates': [-73.871516, 40.68538], 'type': 'Point'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.87151581885323',
#   'park_borough': 'BROOKLYN',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:17:35.000',
#   'resolution_description': 'Your complaint has been received by the Police Department and additional information will be available later.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Assigned',
#   'street_name': 'HEMLOCK STREET',
#   'unique_key': '35953304',
#   'x_coordinate_state_plane': '1019884',
#   'y_coordinate_state_plane': '189005'},
#  {':@computed_region_92fq_4b7q': '30',
#   ':@computed_region_efsh_h5xi': '15310',
#   ':@computed_region_f5dn_yrer': '54',
#   ':@computed_region_yeji_bk3q': '3',
#   'address_type': 'INTERSECTION',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'QUEENS',
#   'city': 'RIDGEWOOD',
#   'community_board': '05 QUEENS',
#   'complaint_type': 'Noise - Commercial',
#   'created_date': '2017-04-16T02:11:32.000',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T10:11:32.000',
#   'facility_type': 'Precinct',
#   'incident_zip': '11385',
#   'intersection_street_1': 'ST NICHOLAS AVENUE',
#   'intersection_street_2': 'PALMETTO STREET',
#   'latitude': '40.70060889413824',
#   'location': {'coordinates': [-73.909939, 40.700609], 'type': 'Point'},
#   'location_type': 'Club/Bar/Restaurant',
#   'longitude': '-73.90993884195109',
#   'park_borough': 'QUEENS',
#   'park_facility_name': 'Unspecified',
#   'resolution_description': 'Your complaint has been forwarded to the New York Police Department for a non-emergency response. 311 will have additional information in 8 hours. Please note your service request number for future reference.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'unique_key': '35953235',
#   'x_coordinate_state_plane': '1009222',
#   'y_coordinate_state_plane': '194540'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:11:22.000',
#   'descriptor': 'Graffiti',
#   'facility_type': 'N/A',
#   'incident_address': '445 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.80977518675513',
#   'location': {'coordinates': [-73.92043, 40.809775], 'type': 'Point'},
#   'location_type': 'Residential',
#   'longitude': '-73.9204296489319',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:11:22.000',
#   'resolution_description': 'The graffiti has been reported. The property owner will be notified that the City will remove the graffiti after 35 days unless the property owner requests to keep the graffiti or remove it himself or herself.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35955359',
#   'x_coordinate_state_plane': '1006277',
#   'y_coordinate_state_plane': '234310'},
#  {':@computed_region_92fq_4b7q': '12',
#   ':@computed_region_efsh_h5xi': '11607',
#   ':@computed_region_f5dn_yrer': '59',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '11 BRONX',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2017-04-16T02:11:21.000',
#   'cross_street_1': 'BEND',
#   'cross_street_2': 'BEND',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T10:11:21.000',
#   'facility_type': 'Precinct',
#   'incident_address': '15 GABRIEL DRIVE',
#   'incident_zip': '10469',
#   'latitude': '40.8636753062546',
#   'location': {'coordinates': [-73.850712, 40.863675], 'type': 'Point'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.85071218550821',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:24:09.000',
#   'resolution_description': 'Your complaint has been received by the Police Department and additional information will be available later.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Assigned',
#   'street_name': 'GABRIEL DRIVE',
#   'unique_key': '35950077',
#   'x_coordinate_state_plane': '1025543',
#   'y_coordinate_state_plane': '253973'},
#  {':@computed_region_92fq_4b7q': '35',
#   ':@computed_region_efsh_h5xi': '10932',
#   ':@computed_region_f5dn_yrer': '49',
#   ':@computed_region_yeji_bk3q': '5',
#   'address_type': 'ADDRESS',
#   'agency': 'DSNY',
#   'agency_name': 'Department of Sanitation',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '01 BRONX',
#   'complaint_type': 'Graffiti',
#   'created_date': '2017-04-16T02:11:07.000',
#   'descriptor': 'Graffiti',
#   'facility_type': 'N/A',
#   'incident_address': '443 EAST  140 STREET',
#   'incident_zip': '10454',
#   'latitude': '40.80979443220791',
#   'location': {'coordinates': [-73.920477, 40.809794], 'type': 'Point'},
#   'longitude': '-73.92047658715956',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T02:11:07.000',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST  140 STREET',
#   'unique_key': '35954480',
#   'x_coordinate_state_plane': '1006264',
#   'y_coordinate_state_plane': '234317'},
#  {':@computed_region_92fq_4b7q': '46',
#   ':@computed_region_efsh_h5xi': '24016',
#   ':@computed_region_f5dn_yrer': '62',
#   ':@computed_region_yeji_bk3q': '3',
#   'address_type': 'INTERSECTION',
#   'agency': 'NYPD',
# ...
#   'closed_date': '2017-04-16T00:56:13.000',
#   'community_board': '09 QUEENS',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2017-04-15T22:53:07.000',
#   'cross_street_1': '121 STREET',
#   'cross_street_2': '123 STREET',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T06:53:07.000',
#   'facility_type': 'Precinct',
#   'incident_address': '121-09 97 AVENUE',
#   'incident_zip': '11419',
#   'latitude': '40.69182290623438',
#   'location': {'coordinates': [-73.824358, 40.691823], 'type': 'Point'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.82435836094021',
#   'park_borough': 'QUEENS',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T00:56:13.000',
#   'resolution_description': 'The Police Department responded to the complaint and took action to fix the condition.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Closed',
#   'street_name': '97 AVENUE',
#   'unique_key': '35953308',
#   'x_coordinate_state_plane': '1032958',
#   'y_coordinate_state_plane': '191375'},
#  {':@computed_region_92fq_4b7q': '49',
#   ':@computed_region_efsh_h5xi': '17213',
#   ':@computed_region_f5dn_yrer': '69',
#   ':@computed_region_yeji_bk3q': '2',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'BROOKLYN',
#   'city': 'BROOKLYN',
#   'closed_date': '2017-04-15T23:45:52.000',
#   'community_board': '03 BROOKLYN',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2017-04-15T22:53:00.000',
#   'cross_street_1': 'THROOP AVENUE',
#   'cross_street_2': 'MARCUS GARVEY BOULEVARD',
#   'descriptor': 'Loud Talking',
#   'due_date': '2017-04-16T06:53:00.000',
#   'facility_type': 'Precinct',
#   'incident_address': '249 HART STREET',
#   'incident_zip': '11206',
#   'latitude': '40.69404716480955',
#   'location': {'coordinates': [-73.941216, 40.694047], 'type': 'Point'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.94121647019418',
#   'park_borough': 'BROOKLYN',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-15T23:45:52.000',
#   'resolution_description': 'The Police Department responded to the complaint and with the information available observed no evidence of the violation at that time.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Closed',
#   'street_name': 'HART STREET',
#   'unique_key': '35951686',
#   'x_coordinate_state_plane': '1000551',
#   'y_coordinate_state_plane': '192142'},
#  {':@computed_region_92fq_4b7q': '39',
#   ':@computed_region_efsh_h5xi': '13091',
#   ':@computed_region_f5dn_yrer': '47',
#   ':@computed_region_yeji_bk3q': '4',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'MANHATTAN',
#   'city': 'NEW YORK',
#   'community_board': '12 MANHATTAN',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2017-04-15T22:52:58.000',
#   'cross_street_1': 'WEST 186 STREET',
#   'cross_street_2': 'WEST 187 STREET',
#   'descriptor': 'Banging/Pounding',
#   'due_date': '2017-04-16T06:52:58.000',
#   'facility_type': 'Precinct',
#   'incident_address': '121 BENNETT AVENUE',
#   'incident_zip': '10033',
#   'latitude': '40.8538561491982',
#   'location': {'coordinates': [-73.934937, 40.853856], 'type': 'Point'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.93493731056213',
#   'park_borough': 'MANHATTAN',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T00:40:55.000',
#   'resolution_description': 'Your complaint has been received by the Police Department and additional information will be available later.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Assigned',
#   'street_name': 'BENNETT AVENUE',
#   'unique_key': '35954000',
#   'x_coordinate_state_plane': '1002249',
#   'y_coordinate_state_plane': '250367'},
#  {':@computed_region_92fq_4b7q': '41',
#   ':@computed_region_efsh_h5xi': '24012',
#   ':@computed_region_f5dn_yrer': '46',
#   ':@computed_region_yeji_bk3q': '3',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'QUEENS',
#   'city': 'OZONE PARK',
#   'closed_date': '2017-04-16T00:56:13.000',
#   'community_board': '09 QUEENS',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2017-04-15T22:52:18.000',
#   'cross_street_1': '97 AVENUE',
#   'cross_street_2': '101 AVENUE',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T06:52:18.000',
#   'facility_type': 'Precinct',
#   'incident_address': '97-17 89 STREET',
#   'incident_zip': '11416',
#   'latitude': '40.68423655500401',
#   'location': {'coordinates': [-73.851817, 40.684237], 'type': 'Point'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.85181700207251',
#   'park_borough': 'QUEENS',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T00:56:13.000',
#   'resolution_description': 'The Police Department responded to the complaint and took action to fix the condition.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Closed',
#   'street_name': '89 STREET',
#   'unique_key': '35950651',
#   'x_coordinate_state_plane': '1025348',
#   'y_coordinate_state_plane': '188597'},
#  {':@computed_region_92fq_4b7q': '45',
#   ':@computed_region_efsh_h5xi': '17616',
#   ':@computed_region_f5dn_yrer': '1',
#   ':@computed_region_yeji_bk3q': '2',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'BROOKLYN',
#   'city': 'BROOKLYN',
#   'closed_date': '2017-04-16T00:37:47.000',
#   'community_board': '11 BROOKLYN',
#   'complaint_type': 'Illegal Parking',
#   'created_date': '2017-04-15T22:52:05.000',
#   'cross_street_1': '82 STREET',
#   'cross_street_2': '83 STREET',
#   'descriptor': 'Blocked Hydrant',
#   'due_date': '2017-04-16T06:52:05.000',
#   'facility_type': 'Precinct',
#   'incident_address': '8213 24 AVENUE',
#   'incident_zip': '11214',
#   'latitude': '40.601397575398394',
#   'location': {'coordinates': [-73.987155, 40.601398], 'type': 'Point'},
#   'location_type': 'Street/Sidewalk',
#   'longitude': '-73.98715478376046',
#   'park_borough': 'BROOKLYN',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-16T00:37:47.000',
#   'resolution_description': 'The Police Department issued a summons in response to the complaint.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Closed',
#   'street_name': '24 AVENUE',
#   'unique_key': '35950943',
#   'x_coordinate_state_plane': '987817',
#   'y_coordinate_state_plane': '158382'},
#  {':@computed_region_92fq_4b7q': '24',
#   ':@computed_region_efsh_h5xi': '24670',
#   ':@computed_region_f5dn_yrer': '41',
#   ':@computed_region_yeji_bk3q': '3',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'QUEENS',
#   'city': 'JAMAICA',
#   'closed_date': '2017-04-15T23:14:16.000',
#   'community_board': '12 QUEENS',
#   'complaint_type': 'Noise - Commercial',
#   'created_date': '2017-04-15T22:51:35.000',
#   'cross_street_1': '144 STREET',
#   'cross_street_2': '144 PLACE',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T06:51:35.000',
#   'facility_type': 'Precinct',
#   'incident_address': '144-07 JAMAICA AVENUE',
#   'incident_zip': '11435',
#   'latitude': '40.70222399413133',
#   'location': {'coordinates': [-73.81121, 40.702224], 'type': 'Point'},
#   'location_type': 'Club/Bar/Restaurant',
#   'longitude': '-73.81121021895017',
#   'park_borough': 'QUEENS',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-15T23:14:16.000',
#   'resolution_description': 'The Police Department responded to the complaint and took action to fix the condition.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Closed',
#   'street_name': 'JAMAICA AVENUE',
#   'unique_key': '35954133',
#   'x_coordinate_state_plane': '1036596',
#   'y_coordinate_state_plane': '195172'},
#  {':@computed_region_92fq_4b7q': '34',
#   ':@computed_region_efsh_h5xi': '15309',
#   ':@computed_region_f5dn_yrer': '54',
#   ':@computed_region_yeji_bk3q': '3',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'QUEENS',
#   'city': 'MIDDLE VILLAGE',
#   'community_board': '05 QUEENS',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2017-04-15T22:51:17.000',
#   'cross_street_1': '67 DRIVE',
#   'cross_street_2': '68 AVENUE',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T06:51:17.000',
#   'facility_type': 'Precinct',
#   'incident_address': '67-59 79 STREET',
#   'incident_zip': '11379',
#   'latitude': '40.71166069151893',
#   'location': {'coordinates': [-73.873467, 40.711661], 'type': 'Point'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.87346709431037',
#   'park_borough': 'QUEENS',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-15T23:10:13.000',
#   'resolution_description': 'Your complaint has been received by the Police Department and additional information will be available later.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Assigned',
#   'street_name': '79 STREET',
#   'unique_key': '35949911',
#   'x_coordinate_state_plane': '1019329',
#   'y_coordinate_state_plane': '198579'},
#  {':@computed_region_92fq_4b7q': '27',
#   ':@computed_region_efsh_h5xi': '17619',
#   ':@computed_region_f5dn_yrer': '14',
#   ':@computed_region_yeji_bk3q': '2',
#   'address_type': 'ADDRESS',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'borough': 'BROOKLYN',
#   'city': 'BROOKLYN',
#   'closed_date': '2017-04-15T23:08:11.000',
#   'community_board': '06 BROOKLYN',
#   'complaint_type': 'Noise - Street/Sidewalk',
#   'created_date': '2017-04-15T22:51:13.000',
#   'cross_street_1': 'BERGEN STREET',
#   'cross_street_2': '6 AVENUE',
#   'descriptor': 'Loud Music/Party',
#   'due_date': '2017-04-16T06:51:13.000',
#   'facility_type': 'Precinct',
#   'incident_address': '240 FLATBUSH AVENUE',
#   'incident_zip': '11217',
#   'latitude': '40.680398694255864',
#   'location': {'coordinates': [-73.974802, 40.680399], 'type': 'Point'},
#   'location_type': 'Street/Sidewalk',
#   'longitude': '-73.97480191514879',
#   'park_borough': 'BROOKLYN',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-15T23:08:11.000',
#   'resolution_description': 'The Police Department responded to the complaint and took action to fix the condition.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_not_found': 'N',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Closed',
#   'street_name': 'FLATBUSH AVENUE',
#   'unique_key': '35952470',
#   'x_coordinate_state_plane': '991239',
#   'y_coordinate_state_plane': '187165'},
#  {':@computed_region_92fq_4b7q': '1',
#   ':@computed_region_efsh_h5xi': '12425',
#   ':@computed_region_f5dn_yrer': '23',
#   ':@computed_region_yeji_bk3q': '4',
#   'address_type': 'ADDRESS',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'borough': 'MANHATTAN',
#   'city': 'NEW YORK',
#   'community_board': '08 MANHATTAN',
#   'complaint_type': 'HEAT/HOT WATER',
#   'created_date': '2017-04-15T22:51:08.000',
#   'descriptor': 'ENTIRE BUILDING',
#   'facility_type': 'N/A',
#   'incident_address': '218 EAST   84 STREET',
#   'incident_zip': '10028',
#   'latitude': '40.77723561133314',
#   'location': {'coordinates': [-73.954329, 40.777236], 'type': 'Point'},
#   'location_type': 'RESIDENTIAL BUILDING',
#   'longitude': '-73.95432907567086',
#   'park_borough': 'MANHATTAN',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-15T00:00:00.000',
#   'resolution_description': 'The following complaint conditions are still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': 'EAST   84 STREET',
#   'unique_key': '35949696',
#   'x_coordinate_state_plane': '996899',
#   'y_coordinate_state_plane': '222448'},
#  {':@computed_region_92fq_4b7q': '10',
#   ':@computed_region_efsh_h5xi': '12080',
#   ':@computed_region_f5dn_yrer': '12',
#   ':@computed_region_yeji_bk3q': '4',
#   'address_type': 'ADDRESS',
#   'agency': 'HPD',
#   'agency_name': 'Department of Housing Preservation and Development',
#   'borough': 'MANHATTAN',
#   'city': 'NEW YORK',
#   'community_board': '04 MANHATTAN',
#   'complaint_type': 'DOOR/WINDOW',
#   'created_date': '2017-04-15T22:51:01.000',
#   'descriptor': 'DOOR',
#   'facility_type': 'N/A',
#   'incident_address': '534 9 AVENUE',
#   'incident_zip': '10018',
#   'latitude': '40.75685655817479',
#   'location': {'coordinates': [-73.993763, 40.756857], 'type': 'Point'},
#   'location_type': 'RESIDENTIAL BUILDING',
#   'longitude': '-73.99376273153837',
#   'park_borough': 'MANHATTAN',
#   'park_facility_name': 'Unspecified',
#   'resolution_action_updated_date': '2017-04-15T00:00:00.000',
#   'resolution_description': 'The following complaint conditions are still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection.',
#   'school_address': 'Unspecified',
#   'school_city': 'Unspecified',
#   'school_code': 'Unspecified',
#   'school_name': 'Unspecified',
#   'school_number': 'Unspecified',
#   'school_phone_number': 'Unspecified',
#   'school_region': 'Unspecified',
#   'school_state': 'Unspecified',
#   'school_zip': 'Unspecified',
#   'status': 'Open',
#   'street_name': '9 AVENUE',
#   'unique_key': '35954633',
#   'x_coordinate_state_plane': '985978',
#   'y_coordinate_state_plane': '215020'}]
